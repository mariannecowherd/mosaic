# %%
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from constants import *

# %%
data_dir = 'users/marianne/documents/data/'
data_dir = 'c:/users/marianne/documents/data/'
perims = gpd.read_file(data_dir + 'Interagency_Fire_Perimeter_History/InteragencyFirePerimeterHistory.shp')

# %%
sn_watersheds = gpd.read_file('c:/users/marianne/documents/pe_snow_fires/data/watersheds.gdf')
fires_sn = gpd.sjoin(perims,sn_watersheds)
sn_watersheds=sn_watersheds.to_crs('epsg:4326')
f,ax=plt.subplots(figsize=(20,20))
fires_sn.plot(ax=ax)
# Out:
# C:\Users\Marianne\AppData\Local\Temp/ipykernel_21832/1202630037.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: EPSG:26910
#
#   fires_sn = gpd.sjoin(perims,sn_watersheds)
# <AxesSubplot:>

# %%
data = perims['FIRE_YEAR_']
data = data[(data>1983) & (data<2030)]
plt.hist(data)
# Out:
# (array([ 5387.,  6027.,  3961.,  5737.,  6081.,  7895.,  8939.,  7460.,
#          9388., 10275.]),
#  array([1984. , 1987.6, 1991.2, 1994.8, 1998.4, 2002. , 2005.6, 2009.2,
#         2012.8, 2016.4, 2020. ]),
#  <BarContainer object of 10 artists>)

# %%
sn = gpd.read_file('/users/marianne/documents/pe_snow_fires/data/sn_watersheds.shp')
sn_fires = gpd.sjoin(perims,sn, how ='inner',op='intersects')
f,ax=plt.subplots()
sn_fires.plot(ax=ax,alpha=0.7,color= sn_fires['FIRE_YEAR_'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pj/dwdbrbvs73j111lmlw52vz8m0000gn/T/ipykernel_6252/2704016525.py in <module>
#       2 sn_fires = gpd.sjoin(perims,sn, how ='inner',op='intersects')
#       3 f,ax=plt.subplots()
# ----> 4 sn_fires.plot(ax=ax,alpha=0.7,color= sn_fires['FIRE_YEAR_'])
#
# ~/opt/anaconda3/envs/earthenv/lib/python3.9/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     923             kind = kwargs.pop("kind", "geo")
#     924             if kind == "geo":
# --> 925                 return plot_dataframe(data, *args, **kwargs)
#     926             if kind in self._pandas_kinds:
#     927                 # Access pandas plots
#
# ...

# %%
plt.hist(sn_fires['FIRE_YEAR_'][(sn_fires['FIRE_YEAR_']>1900) & (sn_fires['FIRE_YEAR_']<2030)])
# Out:
# (array([ 190.,  878.,  647.,  601., 1640., 1423., 1734., 2788., 3257.,
#         3702.]),
#  array([1903. , 1914.7, 1926.4, 1938.1, 1949.8, 1961.5, 1973.2, 1984.9,
#         1996.6, 2008.3, 2020. ]),
#  <BarContainer object of 10 artists>)
