# %%
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from constants import *

# %%
data_dir = '/users/marianne/documents/data/'
perims = gpd.read_file(data_dir + 'Interagency_Fire_Perimeter_History/InteragencyFirePerimeterHistory.shp')
# Out:
#            FID  OBJECTID   MAP_METHOD  DATE_CUR COMMENTS  \
# 0            1         1   GPS Ground  20200623     None
# 1            2         2   GPS Ground  20200604     None
# 2            3         3   GPS Ground  20200301     None
# 3            4         4   GPS Ground  20200401     None
# 4            5         5   GPS Ground  20200419     None
# ...        ...       ...          ...       ...      ...
# 107862  107863    107863  GPS-Unknown  20210204     None
# 107863  107864    107864  GPS-Unknown  20210204     None
# 107864  107865    107865  GPS-Unknown  20210204     None
# 107865  107866    107866  GPS-Unknown  20210204     None
# 107866  107867    107867  GPS-Unknown  20210204     None
#
#                                         GEO_ID IRWINID         UNQE_FIRE_  \
# 0                                            1    None               None
# 1                                            2    None               None
# 2                                            3    None               None
# 3                                            4    None               None
# 4                                            5    None               None
# ...                                        ...     ...                ...
# 107862  {644B64C8-72F1-4C3F-985F-40830FA1C9A2}    None  2020-ORBUD-002105
# 107863  {7A7F2DF4-02CA-4B15-9EBB-62F69CB2C05B}    None  2020-ORMAF-002022
# 107864  {7ED8190D-7AB5-4F7A-A32A-3A292534993F}    None  2020-ORMAR-002006
# 107865  {89A448AD-BEB3-49F8-B26D-CDF4EB94E25B}    None  2020-ORMAR-002006
# 107866  {DE80136E-7BD1-4A38-9446-01DD7D1A72E6}    None  2020-ORMAF-002022
#
#        FIRE_YEAR LOCAL_NUM  ... POO_RESP_I FEATURE_CA   GIS_ACRES USER_NAME  \
# 0           2020  00013212  ...       None   Wildfire  109.602501      None
# 1           2020  00011799  ...       None   Wildfire  685.585022      None
# 2           2020  00018493  ...       None   Wildfire   27.300480      None
# 3           2020  00007619  ...       None   Wildfire   12.931550      None
# 4           2020  00008471  ...       None   Wildfire   10.315960      None
# ...          ...       ...  ...        ...        ...         ...       ...
# 107862      2020      2105  ...       None   Wildfire  150.294296      None
# 107863      2020      2022  ...       None   Wildfire    0.440840      None
# 107864      2020      2006  ...       None   Wildfire    0.810287      None
# 107865      2020      2006  ...       None   Wildfire    4.672495      None
# 107866      2020      2022  ...       None   Wildfire    0.005868      None
#
#               SOURCE AGENCY FIRE_YEAR_ SHAPE_Leng    SHAPE_Area  \
# 0       CalFire FRAP    CDF     2020.0   0.035733  4.605000e-05
# 1       CalFire FRAP    CDF     2020.0   0.101178  2.878109e-04
# 2       CalFire FRAP    CDF     2020.0   0.017450  1.146338e-05
# 3       CalFire FRAP    CDF     2020.0   0.016557  5.438849e-06
# 4       CalFire FRAP    CDF     2020.0   0.010920  4.370757e-06
# ...              ...    ...        ...        ...           ...
# 107862           BLM    BLM     2020.0   0.055525  6.694919e-05
# 107863           BLM    BLM     2020.0   0.002167  1.999611e-07
# 107864           BLM    BLM     2020.0   0.002324  3.636878e-07
# 107865           BLM    BLM     2020.0   0.009759  2.097167e-06
# 107866           BLM    BLM     2020.0   0.000247  2.661735e-09
#
#                                                  geometry
# 0       POLYGON ((-121.34840 38.88999, -121.34835 38.8...
# 1       POLYGON ((-121.35275 38.82038, -121.35267 38.8...
# 2       POLYGON ((-121.33333 38.84558, -121.33311 38.8...
# 3       POLYGON ((-121.27317 38.96308, -121.27304 38.9...
# 4       POLYGON ((-121.30065 39.48714, -121.30041 39.4...
# ...                                                   ...
# 107862  POLYGON ((-118.36847 42.82102, -118.36759 42.8...
# 107863  POLYGON ((-119.09742 43.93243, -119.09744 43.9...
# 107864  POLYGON ((-118.83986 43.29000, -118.84004 43.2...
# 107865  POLYGON ((-118.85345 43.28866, -118.85381 43.2...
# 107866  POLYGON ((-119.09745 43.93241, -119.09745 43.9...
#
# [107867 rows x 22 columns]

# %%
f,ax=plt.subplots(figsize=(20,20))
perims.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
data = perims['FIRE_YEAR_']
data = data[(data>1983) & (data<2030)]
plt.hist(data)
# Out:
# (array([ 5387.,  6027.,  3961.,  5737.,  6081.,  7895.,  8939.,  7460.,
#          9388., 10275.]),
#  array([1984. , 1987.6, 1991.2, 1994.8, 1998.4, 2002. , 2005.6, 2009.2,
#         2012.8, 2016.4, 2020. ]),
#  <BarContainer object of 10 artists>)

# %%
sn = gpd.read_file('/users/marianne/documents/pe_snow_fires/data/sn_watersheds.shp')
sn_fires = gpd.sjoin(perims,sn, how ='inner',op='intersects')
f,ax=plt.subplots()
sn_fires.plot(ax=ax,alpha=0.7,color= sn_fires['FIRE_YEAR_'])

# %%
plt.hist(sn_fires['FIRE_YEAR_'][(sn_fires['FIRE_YEAR_']>1900) & (sn_fires['FIRE_YEAR_']<2030)])
# Out:
# (array([ 190.,  878.,  647.,  601., 1640., 1423., 1734., 2788., 3257.,
#         3702.]),
#  array([1903. , 1914.7, 1926.4, 1938.1, 1949.8, 1961.5, 1973.2, 1984.9,
#         1996.6, 2008.3, 2020. ]),
#  <BarContainer object of 10 artists>)
